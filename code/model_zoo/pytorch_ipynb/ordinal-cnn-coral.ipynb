# %% [markdown]
# *Accompanying code examples of the book "Introduction to Artificial Neural Networks and Deep Learning: A Practical Guide with Applications in Python" by [Sebastian Raschka](https://sebastianraschka.com). All code examples are released under the [MIT license](https://github.com/rasbt/deep-learning-book/blob/master/LICENSE). If you find this content useful, please consider supporting the work by buying a [copy of the book](https://leanpub.com/ann-and-deeplearning).*
#
# Other code examples and content are available on [GitHub](https://github.com/rasbt/deep-learning-book). The PDF and ebook versions of the book are available through [Leanpub](https://leanpub.com/ann-and-deeplearning).

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.6.8
# IPython 7.2.0
#
# torch 1.1.0

# %% [markdown]
# - Runs on CPU or GPU (if available)

# %% [markdown]
# # Model Zoo -- Ordinal Regression CNN -- CORAL

# %% [markdown]
# Implementation of a method for ordinal regression, CORAL [1] (COnsistent RAnk Logits) applied to predicting age from face images in the AFAD [2] (Asian Face) dataset using a simple AlexNet [3] convolutional network architecture.
#
# - [1] Cao, Wenzhi, Vahid Mirjalili, and Sebastian Raschka. "[Consistent Rank Logits for Ordinal Regression with Convolutional Neural Networks](https://arxiv.org/abs/1901.07884)." arXiv preprint arXiv:1901.07884 (2019).
# - [2] Niu, Zhenxing, Mo Zhou, Le Wang, Xinbo Gao, and Gang Hua. "[Ordinal regression with multiple output cnn for age estimation](https://ieeexplore.ieee.org/document/7780901/)." In Proceedings of the IEEE conference on computer vision and pattern recognition, pp. 4920-4928. 2016.
# - [3] Krizhevsky, Alex, Ilya Sutskever, and Geoffrey E. Hinton. "[Imagenet classification with deep convolutional neural networks](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networ)." In Advances in neural information processing systems, pp. 1097-1105. 2012.

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import pandas as pd
import os

import torch.nn as nn
import torch.nn.functional as F
import torch

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
from PIL import Image


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Downloading the Dataset

# %%
# !git clone https://github.com/afad-dataset/tarball.git
# Out:
# fatal: destination path 'tarball' already exists and is not an empty directory.

# %%
# !cat tarball/AFAD-Full.tar.xz* > AFAD-Full.tar.xz

# %%
# !tar xf AFAD-Full.tar.xz

# %%
# !wget https://sebastianraschka.com/datasets/afad/test_set_class0_max25.csv
# Out:
# --2019-06-02 22:33:32--  https://sebastianraschka.com/datasets/afad/test_set_class0_max25.csv
# Resolving sebastianraschka.com (sebastianraschka.com)... 67.20.73.179
# Connecting to sebastianraschka.com (sebastianraschka.com)|67.20.73.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1331840 (1.3M) [text/csv]
# Saving to: ‘test_set_class0_max25.csv.9’
#
# test_set_class0_max 100%[===================>]   1.27M  4.49MB/s    in 0.3s
#
# 2019-06-02 22:33:33 (4.49 MB/s) - ‘test_set_class0_max25.csv.9’ saved [1331840/1331840]

# %%
# !wget https://sebastianraschka.com/datasets/afad/train_set_class0_max25.csv
# Out:
# --2019-06-02 22:33:33--  https://sebastianraschka.com/datasets/afad/train_set_class0_max25.csv
# Resolving sebastianraschka.com (sebastianraschka.com)... 67.20.73.179
# Connecting to sebastianraschka.com (sebastianraschka.com)|67.20.73.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5352951 (5.1M) [text/csv]
# Saving to: ‘train_set_class0_max25.csv.9’
#
# train_set_class0_ma 100%[===================>]   5.10M  12.5MB/s    in 0.4s
#
# 2019-06-02 22:33:34 (12.5 MB/s) - ‘train_set_class0_max25.csv.9’ saved [5352951/5352951]

# %% [markdown]
# ## Settings

# %%
##########################
### SETTINGS
##########################

# Device
DEVICE = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

NUM_WORKERS = 8

NUM_CLASSES = 26
BATCH_SIZE = 256
NUM_EPOCHS = 150
LEARNING_RATE = 0.00005
RANDOM_SEED = 123

TRAIN_CSV_PATH = 'train_set_class0_max25.csv'
TEST_CSV_PATH = 'test_set_class0_max25.csv'
IMAGE_PATH = 'AFAD-Full'

# %% [markdown]
# ## Dataset Loaders

# %%
class AFADDatasetAge(Dataset):
    """Custom Dataset for loading AFAD face images"""

    def __init__(self, csv_path, img_dir, transform=None):

        df = pd.read_csv(csv_path, index_col=0)
        self.img_dir = img_dir
        self.csv_path = csv_path
        self.img_paths = df['path']
        self.y = df['age'].values
        self.transform = transform

    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir,
                                      self.img_paths[index]))

        if self.transform is not None:
            img = self.transform(img)

        label = self.y[index]
        levels = [1]*label + [0]*(NUM_CLASSES - 1 - label)
        levels = torch.tensor(levels, dtype=torch.float32)

        return img, label, levels

    def __len__(self):
        return self.y.shape[0]


custom_transform = transforms.Compose([transforms.Resize((128, 128)),
                                       transforms.RandomCrop((120, 120)),
                                       transforms.ToTensor()])

train_dataset = AFADDatasetAge(csv_path=TRAIN_CSV_PATH,
                               img_dir=IMAGE_PATH,
                               transform=custom_transform)


custom_transform2 = transforms.Compose([transforms.Resize((128, 128)),
                                        transforms.CenterCrop((120, 120)),
                                        transforms.ToTensor()])

test_dataset = AFADDatasetAge(csv_path=TEST_CSV_PATH,
                              img_dir=IMAGE_PATH,
                              transform=custom_transform2)


train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=NUM_WORKERS)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=NUM_WORKERS)

# %% [markdown]
# ## Model

# %%
##########################
# MODEL
##########################

class AlexNet(nn.Module):

    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.num_classes = num_classes
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
        )

        self.fc = nn.Linear(4096, 1, bias=False)
        self.linear_1_bias = nn.Parameter(torch.zeros(self.num_classes-1).float())

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        x = self.classifier(x)

        logits = self.fc(x)
        logits = logits + self.linear_1_bias
        probas = torch.sigmoid(logits)
        return logits, probas

# %%
###########################################
# Initialize Cost, Model, and Optimizer
###########################################

def cost_fn(logits, levels):
    val = (-torch.sum((F.logsigmoid(logits)*levels
                      + (F.logsigmoid(logits) - logits)*(1-levels)),
           dim=1))
    return torch.mean(val)


torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)
model = AlexNet(NUM_CLASSES)

model.to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ## Training

# %%
def compute_mae_and_mse(model, data_loader, device):
    mae, mse, num_examples = 0, 0, 0
    for i, (features, targets, levels) in enumerate(data_loader):

        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        predict_levels = probas > 0.5
        predicted_labels = torch.sum(predict_levels, dim=1)
        num_examples += targets.size(0)
        mae += torch.sum(torch.abs(predicted_labels - targets))
        mse += torch.sum((predicted_labels - targets)**2)
    mae = mae.float() / num_examples
    mse = mse.float() / num_examples
    return mae, mse


start_time = time.time()
for epoch in range(NUM_EPOCHS):

    model.train()
    for batch_idx, (features, targets, levels) in enumerate(train_loader):

        features = features.to(DEVICE)
        targets = targets
        targets = targets.to(DEVICE)
        levels = levels.to(DEVICE)

        # FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = cost_fn(logits, levels)
        optimizer.zero_grad()

        cost.backward()

        # UPDATE MODEL PARAMETERS
        optimizer.step()

        # LOGGING
        if not batch_idx % 150:
            s = ('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                 % (epoch+1, NUM_EPOCHS, batch_idx,
                     len(train_dataset)//BATCH_SIZE, cost))
            print(s)

    s = 'Time elapsed: %.2f min' % ((time.time() - start_time)/60)
    print(s)
# Out:
# Epoch: 001/150 | Batch 0000/0514 | Cost: 17.3278
# Epoch: 001/150 | Batch 0150/0514 | Cost: 16.5859
# Epoch: 001/150 | Batch 0300/0514 | Cost: 16.4164
# Epoch: 001/150 | Batch 0450/0514 | Cost: 16.0580
# Time elapsed: 0.59 min
# Epoch: 002/150 | Batch 0000/0514 | Cost: 16.2263
# Epoch: 002/150 | Batch 0150/0514 | Cost: 16.0722
# Epoch: 002/150 | Batch 0300/0514 | Cost: 15.9567
# Epoch: 002/150 | Batch 0450/0514 | Cost: 16.0964
# Time elapsed: 1.18 min
# Epoch: 003/150 | Batch 0000/0514 | Cost: 15.8509
# Epoch: 003/150 | Batch 0150/0514 | Cost: 15.7487
# Epoch: 003/150 | Batch 0300/0514 | Cost: 15.6847
# Epoch: 003/150 | Batch 0450/0514 | Cost: 15.3686
# Time elapsed: 1.78 min
# Epoch: 004/150 | Batch 0000/0514 | Cost: 15.2173
# Epoch: 004/150 | Batch 0150/0514 | Cost: 15.3359
# Epoch: 004/150 | Batch 0300/0514 | Cost: 15.2410
# Epoch: 004/150 | Batch 0450/0514 | Cost: 15.1033
# Time elapsed: 2.39 min
# Epoch: 005/150 | Batch 0000/0514 | Cost: 15.2330
# Epoch: 005/150 | Batch 0150/0514 | Cost: 15.1501
# Epoch: 005/150 | Batch 0300/0514 | Cost: 15.4353
# Epoch: 005/150 | Batch 0450/0514 | Cost: 14.9413
# Time elapsed: 2.99 min
# Epoch: 006/150 | Batch 0000/0514 | Cost: 15.2729
# Epoch: 006/150 | Batch 0150/0514 | Cost: 14.8077
# Epoch: 006/150 | Batch 0300/0514 | Cost: 15.2334
# Epoch: 006/150 | Batch 0450/0514 | Cost: 14.7081
# Time elapsed: 3.59 min
# Epoch: 007/150 | Batch 0000/0514 | Cost: 14.4800
# Epoch: 007/150 | Batch 0150/0514 | Cost: 14.6544
# Epoch: 007/150 | Batch 0300/0514 | Cost: 14.7656
# Epoch: 007/150 | Batch 0450/0514 | Cost: 14.5348
# Time elapsed: 4.19 min
# Epoch: 008/150 | Batch 0000/0514 | Cost: 14.4789
# Epoch: 008/150 | Batch 0150/0514 | Cost: 14.3794
# Epoch: 008/150 | Batch 0300/0514 | Cost: 14.7573
# Epoch: 008/150 | Batch 0450/0514 | Cost: 14.8278
# Time elapsed: 4.79 min
# Epoch: 009/150 | Batch 0000/0514 | Cost: 14.6097
# Epoch: 009/150 | Batch 0150/0514 | Cost: 14.3443
# Epoch: 009/150 | Batch 0300/0514 | Cost: 14.5179
# Epoch: 009/150 | Batch 0450/0514 | Cost: 14.2957
# Time elapsed: 5.39 min
# Epoch: 010/150 | Batch 0000/0514 | Cost: 14.0440
# Epoch: 010/150 | Batch 0150/0514 | Cost: 13.8444
# Epoch: 010/150 | Batch 0300/0514 | Cost: 14.0243
# Epoch: 010/150 | Batch 0450/0514 | Cost: 14.2746
# Time elapsed: 5.99 min
# Epoch: 011/150 | Batch 0000/0514 | Cost: 13.9430
# Epoch: 011/150 | Batch 0150/0514 | Cost: 13.7966
# Epoch: 011/150 | Batch 0300/0514 | Cost: 14.1551
# Epoch: 011/150 | Batch 0450/0514 | Cost: 14.0288
# Time elapsed: 6.59 min
# Epoch: 012/150 | Batch 0000/0514 | Cost: 14.1800
# Epoch: 012/150 | Batch 0150/0514 | Cost: 13.8919
# Epoch: 012/150 | Batch 0300/0514 | Cost: 13.7294
# Epoch: 012/150 | Batch 0450/0514 | Cost: 14.1620
# Time elapsed: 7.20 min
# Epoch: 013/150 | Batch 0000/0514 | Cost: 13.9520
# Epoch: 013/150 | Batch 0150/0514 | Cost: 13.8412
# Epoch: 013/150 | Batch 0300/0514 | Cost: 13.2180
# Epoch: 013/150 | Batch 0450/0514 | Cost: 13.6274
# Time elapsed: 7.80 min
# Epoch: 014/150 | Batch 0000/0514 | Cost: 13.4447
# Epoch: 014/150 | Batch 0150/0514 | Cost: 13.5500
# Epoch: 014/150 | Batch 0300/0514 | Cost: 13.8115
# Epoch: 014/150 | Batch 0450/0514 | Cost: 13.5434
# Time elapsed: 8.40 min
# Epoch: 015/150 | Batch 0000/0514 | Cost: 13.2764
# Epoch: 015/150 | Batch 0150/0514 | Cost: 13.3771
# Epoch: 015/150 | Batch 0300/0514 | Cost: 13.4614
# Epoch: 015/150 | Batch 0450/0514 | Cost: 13.0683
# Time elapsed: 9.00 min
# Epoch: 016/150 | Batch 0000/0514 | Cost: 12.9784
# Epoch: 016/150 | Batch 0150/0514 | Cost: 13.1734
# Epoch: 016/150 | Batch 0300/0514 | Cost: 13.2348
# Epoch: 016/150 | Batch 0450/0514 | Cost: 13.4751
# Time elapsed: 9.61 min
# Epoch: 017/150 | Batch 0000/0514 | Cost: 12.7747
# Epoch: 017/150 | Batch 0150/0514 | Cost: 13.0233
# Epoch: 017/150 | Batch 0300/0514 | Cost: 12.9745
# Epoch: 017/150 | Batch 0450/0514 | Cost: 12.5344
# Time elapsed: 10.21 min
# Epoch: 018/150 | Batch 0000/0514 | Cost: 12.5944
# Epoch: 018/150 | Batch 0150/0514 | Cost: 12.8494
# Epoch: 018/150 | Batch 0300/0514 | Cost: 12.7405
# Epoch: 018/150 | Batch 0450/0514 | Cost: 12.7435
# Time elapsed: 10.81 min
# Epoch: 019/150 | Batch 0000/0514 | Cost: 12.3734
# Epoch: 019/150 | Batch 0150/0514 | Cost: 12.5414
# Epoch: 019/150 | Batch 0300/0514 | Cost: 12.5676
# Epoch: 019/150 | Batch 0450/0514 | Cost: 12.6086
# Time elapsed: 11.41 min
# Epoch: 020/150 | Batch 0000/0514 | Cost: 12.7620
# Epoch: 020/150 | Batch 0150/0514 | Cost: 12.3584
# Epoch: 020/150 | Batch 0300/0514 | Cost: 12.3852
# Epoch: 020/150 | Batch 0450/0514 | Cost: 12.4803
# Time elapsed: 12.02 min
# Epoch: 021/150 | Batch 0000/0514 | Cost: 11.9697
# Epoch: 021/150 | Batch 0150/0514 | Cost: 12.6175
# Epoch: 021/150 | Batch 0300/0514 | Cost: 12.6110
# Epoch: 021/150 | Batch 0450/0514 | Cost: 12.7169
# Time elapsed: 12.62 min
# Epoch: 022/150 | Batch 0000/0514 | Cost: 12.2603
# Epoch: 022/150 | Batch 0150/0514 | Cost: 12.1282
# Epoch: 022/150 | Batch 0300/0514 | Cost: 12.2569
# Epoch: 022/150 | Batch 0450/0514 | Cost: 11.9220
# Time elapsed: 13.23 min
# Epoch: 023/150 | Batch 0000/0514 | Cost: 12.3147
# Epoch: 023/150 | Batch 0150/0514 | Cost: 11.9454
# Epoch: 023/150 | Batch 0300/0514 | Cost: 11.9409
# Epoch: 023/150 | Batch 0450/0514 | Cost: 12.2188
# Time elapsed: 13.83 min
# Epoch: 024/150 | Batch 0000/0514 | Cost: 11.5581
# Epoch: 024/150 | Batch 0150/0514 | Cost: 11.9249
# Epoch: 024/150 | Batch 0300/0514 | Cost: 11.6874
# Epoch: 024/150 | Batch 0450/0514 | Cost: 12.2641
# Time elapsed: 14.43 min
# Epoch: 025/150 | Batch 0000/0514 | Cost: 11.5186
# Epoch: 025/150 | Batch 0150/0514 | Cost: 11.6463
# Epoch: 025/150 | Batch 0300/0514 | Cost: 11.9017
# Epoch: 025/150 | Batch 0450/0514 | Cost: 11.5750
# Time elapsed: 15.04 min
# Epoch: 026/150 | Batch 0000/0514 | Cost: 11.4738
# Epoch: 026/150 | Batch 0150/0514 | Cost: 11.3520
# Epoch: 026/150 | Batch 0300/0514 | Cost: 11.5864
# Epoch: 026/150 | Batch 0450/0514 | Cost: 11.4802
# Time elapsed: 15.64 min
# Epoch: 027/150 | Batch 0000/0514 | Cost: 11.2448
# Epoch: 027/150 | Batch 0150/0514 | Cost: 11.9377
# Epoch: 027/150 | Batch 0300/0514 | Cost: 11.2396
# Epoch: 027/150 | Batch 0450/0514 | Cost: 11.4985
# Time elapsed: 16.24 min
# Epoch: 028/150 | Batch 0000/0514 | Cost: 11.2164
# Epoch: 028/150 | Batch 0150/0514 | Cost: 11.3911
# Epoch: 028/150 | Batch 0300/0514 | Cost: 11.3427
# Epoch: 028/150 | Batch 0450/0514 | Cost: 11.2373
# Time elapsed: 16.96 min
# Epoch: 029/150 | Batch 0000/0514 | Cost: 11.2399
# Epoch: 029/150 | Batch 0150/0514 | Cost: 11.2797
# Epoch: 029/150 | Batch 0300/0514 | Cost: 11.1650
# Epoch: 029/150 | Batch 0450/0514 | Cost: 11.5542
# Time elapsed: 17.73 min
# Epoch: 030/150 | Batch 0000/0514 | Cost: 10.9942
# Epoch: 030/150 | Batch 0150/0514 | Cost: 10.9423
# Epoch: 030/150 | Batch 0300/0514 | Cost: 10.7606
# Epoch: 030/150 | Batch 0450/0514 | Cost: 11.0371
# Time elapsed: 18.51 min
# Epoch: 031/150 | Batch 0000/0514 | Cost: 11.0036
# Epoch: 031/150 | Batch 0150/0514 | Cost: 10.9278
# Epoch: 031/150 | Batch 0300/0514 | Cost: 10.9698
# Epoch: 031/150 | Batch 0450/0514 | Cost: 10.7057
# Time elapsed: 19.29 min
# Epoch: 032/150 | Batch 0000/0514 | Cost: 10.8587
# Epoch: 032/150 | Batch 0150/0514 | Cost: 10.4832
# Epoch: 032/150 | Batch 0300/0514 | Cost: 10.9220
# Epoch: 032/150 | Batch 0450/0514 | Cost: 10.9515
# Time elapsed: 20.07 min
# Epoch: 033/150 | Batch 0000/0514 | Cost: 10.8315
# Epoch: 033/150 | Batch 0150/0514 | Cost: 10.4355
# Epoch: 033/150 | Batch 0300/0514 | Cost: 10.2922
# Epoch: 033/150 | Batch 0450/0514 | Cost: 10.7836
# Time elapsed: 20.85 min
# Epoch: 034/150 | Batch 0000/0514 | Cost: 10.6802
# Epoch: 034/150 | Batch 0150/0514 | Cost: 10.3280
# Epoch: 034/150 | Batch 0300/0514 | Cost: 10.8385
# Epoch: 034/150 | Batch 0450/0514 | Cost: 10.2332
# Time elapsed: 21.63 min
# Epoch: 035/150 | Batch 0000/0514 | Cost: 10.2084
# Epoch: 035/150 | Batch 0150/0514 | Cost: 10.1907
# Epoch: 035/150 | Batch 0300/0514 | Cost: 10.2727
# Epoch: 035/150 | Batch 0450/0514 | Cost: 10.4008
# Time elapsed: 22.40 min
# Epoch: 036/150 | Batch 0000/0514 | Cost: 10.3970
# Epoch: 036/150 | Batch 0150/0514 | Cost: 10.4277
# Epoch: 036/150 | Batch 0300/0514 | Cost: 10.3316
# Epoch: 036/150 | Batch 0450/0514 | Cost: 10.1243
# Time elapsed: 23.17 min
# Epoch: 037/150 | Batch 0000/0514 | Cost: 10.0543
# Epoch: 037/150 | Batch 0150/0514 | Cost: 9.9127
# Epoch: 037/150 | Batch 0300/0514 | Cost: 10.3791
# Epoch: 037/150 | Batch 0450/0514 | Cost: 10.1006
# Time elapsed: 23.96 min
# Epoch: 038/150 | Batch 0000/0514 | Cost: 9.9163
# Epoch: 038/150 | Batch 0150/0514 | Cost: 9.7706
# Epoch: 038/150 | Batch 0300/0514 | Cost: 9.9947
# Epoch: 038/150 | Batch 0450/0514 | Cost: 10.1071
# Time elapsed: 24.75 min
# Epoch: 039/150 | Batch 0000/0514 | Cost: 9.9456
# Epoch: 039/150 | Batch 0150/0514 | Cost: 9.8816
# Epoch: 039/150 | Batch 0300/0514 | Cost: 9.6616
# Epoch: 039/150 | Batch 0450/0514 | Cost: 9.7334
# Time elapsed: 25.52 min
# Epoch: 040/150 | Batch 0000/0514 | Cost: 9.5974
# Epoch: 040/150 | Batch 0150/0514 | Cost: 9.5162
# Epoch: 040/150 | Batch 0300/0514 | Cost: 9.8083
# Epoch: 040/150 | Batch 0450/0514 | Cost: 9.4232
# Time elapsed: 26.30 min
# Epoch: 041/150 | Batch 0000/0514 | Cost: 9.6748
# Epoch: 041/150 | Batch 0150/0514 | Cost: 9.6801
# Epoch: 041/150 | Batch 0300/0514 | Cost: 9.4648
# Epoch: 041/150 | Batch 0450/0514 | Cost: 9.6346
# Time elapsed: 27.08 min
# Epoch: 042/150 | Batch 0000/0514 | Cost: 9.5483
# Epoch: 042/150 | Batch 0150/0514 | Cost: 9.3940
# Epoch: 042/150 | Batch 0300/0514 | Cost: 9.3132
# Epoch: 042/150 | Batch 0450/0514 | Cost: 9.4660
# Time elapsed: 27.85 min
# Epoch: 043/150 | Batch 0000/0514 | Cost: 9.4102
# Epoch: 043/150 | Batch 0150/0514 | Cost: 9.2997
# Epoch: 043/150 | Batch 0300/0514 | Cost: 9.3356
# Epoch: 043/150 | Batch 0450/0514 | Cost: 9.1661
# Time elapsed: 28.62 min
# Epoch: 044/150 | Batch 0000/0514 | Cost: 9.1798
# Epoch: 044/150 | Batch 0150/0514 | Cost: 9.1283
# Epoch: 044/150 | Batch 0300/0514 | Cost: 9.4395
# Epoch: 044/150 | Batch 0450/0514 | Cost: 9.3488
# Time elapsed: 29.40 min
# Epoch: 045/150 | Batch 0000/0514 | Cost: 8.9584
# Epoch: 045/150 | Batch 0150/0514 | Cost: 9.5143
# Epoch: 045/150 | Batch 0300/0514 | Cost: 9.1815
# Epoch: 045/150 | Batch 0450/0514 | Cost: 9.1812
# Time elapsed: 30.18 min
# Epoch: 046/150 | Batch 0000/0514 | Cost: 9.2138
# Epoch: 046/150 | Batch 0150/0514 | Cost: 9.1687
# Epoch: 046/150 | Batch 0300/0514 | Cost: 9.1729
# Epoch: 046/150 | Batch 0450/0514 | Cost: 8.8825
# Time elapsed: 30.94 min
# Epoch: 047/150 | Batch 0000/0514 | Cost: 8.9620
# Epoch: 047/150 | Batch 0150/0514 | Cost: 8.7136
# Epoch: 047/150 | Batch 0300/0514 | Cost: 8.9485
# Epoch: 047/150 | Batch 0450/0514 | Cost: 8.7152
# Time elapsed: 31.73 min
# Epoch: 048/150 | Batch 0000/0514 | Cost: 8.8893
# Epoch: 048/150 | Batch 0150/0514 | Cost: 8.9836
# Epoch: 048/150 | Batch 0300/0514 | Cost: 8.8676
# Epoch: 048/150 | Batch 0450/0514 | Cost: 8.9226
# Time elapsed: 32.51 min
# Epoch: 049/150 | Batch 0000/0514 | Cost: 8.9263
# Epoch: 049/150 | Batch 0150/0514 | Cost: 9.0293
# Epoch: 049/150 | Batch 0300/0514 | Cost: 8.6957
# Epoch: 049/150 | Batch 0450/0514 | Cost: 8.8683
# Time elapsed: 33.29 min
# Epoch: 050/150 | Batch 0000/0514 | Cost: 8.5623
# Epoch: 050/150 | Batch 0150/0514 | Cost: 8.4698
# Epoch: 050/150 | Batch 0300/0514 | Cost: 8.4534
# Epoch: 050/150 | Batch 0450/0514 | Cost: 8.7129
# Time elapsed: 34.06 min
# Epoch: 051/150 | Batch 0000/0514 | Cost: 8.7646
# Epoch: 051/150 | Batch 0150/0514 | Cost: 8.5717
# Epoch: 051/150 | Batch 0300/0514 | Cost: 8.6663
# Epoch: 051/150 | Batch 0450/0514 | Cost: 8.5693
# Time elapsed: 34.83 min
# Epoch: 052/150 | Batch 0000/0514 | Cost: 8.4289
# Epoch: 052/150 | Batch 0150/0514 | Cost: 8.5382
# Epoch: 052/150 | Batch 0300/0514 | Cost: 8.4452
# Epoch: 052/150 | Batch 0450/0514 | Cost: 8.5683
# Time elapsed: 35.60 min
# Epoch: 053/150 | Batch 0000/0514 | Cost: 8.4886
# Epoch: 053/150 | Batch 0150/0514 | Cost: 8.4739
# Epoch: 053/150 | Batch 0300/0514 | Cost: 8.3817
# Epoch: 053/150 | Batch 0450/0514 | Cost: 8.3861
# Time elapsed: 36.37 min
# Epoch: 054/150 | Batch 0000/0514 | Cost: 8.5377
# Epoch: 054/150 | Batch 0150/0514 | Cost: 8.1863
# Epoch: 054/150 | Batch 0300/0514 | Cost: 8.5994
# Epoch: 054/150 | Batch 0450/0514 | Cost: 8.4356
# Time elapsed: 37.13 min
# Epoch: 055/150 | Batch 0000/0514 | Cost: 8.3484
# Epoch: 055/150 | Batch 0150/0514 | Cost: 8.1454
# Epoch: 055/150 | Batch 0300/0514 | Cost: 8.3032
# Epoch: 055/150 | Batch 0450/0514 | Cost: 8.0134
# Time elapsed: 37.91 min
# Epoch: 056/150 | Batch 0000/0514 | Cost: 8.0732
# Epoch: 056/150 | Batch 0150/0514 | Cost: 8.0146
# Epoch: 056/150 | Batch 0300/0514 | Cost: 8.0091
# Epoch: 056/150 | Batch 0450/0514 | Cost: 8.2825
# Time elapsed: 38.68 min
# Epoch: 057/150 | Batch 0000/0514 | Cost: 7.9819
# Epoch: 057/150 | Batch 0150/0514 | Cost: 8.1078
# Epoch: 057/150 | Batch 0300/0514 | Cost: 8.0636
# Epoch: 057/150 | Batch 0450/0514 | Cost: 7.9582
# Time elapsed: 39.45 min
# Epoch: 058/150 | Batch 0000/0514 | Cost: 8.1871
# Epoch: 058/150 | Batch 0150/0514 | Cost: 8.1145
# Epoch: 058/150 | Batch 0300/0514 | Cost: 8.1840
# Epoch: 058/150 | Batch 0450/0514 | Cost: 8.1721
# Time elapsed: 40.22 min
# Epoch: 059/150 | Batch 0000/0514 | Cost: 7.7999
# Epoch: 059/150 | Batch 0150/0514 | Cost: 7.8783
# Epoch: 059/150 | Batch 0300/0514 | Cost: 8.1344
# Epoch: 059/150 | Batch 0450/0514 | Cost: 7.8850
# Time elapsed: 41.00 min
# Epoch: 060/150 | Batch 0000/0514 | Cost: 7.7544
# Epoch: 060/150 | Batch 0150/0514 | Cost: 7.6941
# Epoch: 060/150 | Batch 0300/0514 | Cost: 7.8114
# Epoch: 060/150 | Batch 0450/0514 | Cost: 7.4800
# Time elapsed: 41.78 min
# Epoch: 061/150 | Batch 0000/0514 | Cost: 7.6744
# Epoch: 061/150 | Batch 0150/0514 | Cost: 7.5612
# Epoch: 061/150 | Batch 0300/0514 | Cost: 7.6638
# Epoch: 061/150 | Batch 0450/0514 | Cost: 7.6121
# Time elapsed: 42.57 min
# Epoch: 062/150 | Batch 0000/0514 | Cost: 7.6735
# Epoch: 062/150 | Batch 0150/0514 | Cost: 7.6204
# Epoch: 062/150 | Batch 0300/0514 | Cost: 7.8317
# Epoch: 062/150 | Batch 0450/0514 | Cost: 7.7826
# Time elapsed: 43.34 min
# Epoch: 063/150 | Batch 0000/0514 | Cost: 7.6590
# Epoch: 063/150 | Batch 0150/0514 | Cost: 7.5504
# Epoch: 063/150 | Batch 0300/0514 | Cost: 7.7998
# Epoch: 063/150 | Batch 0450/0514 | Cost: 7.7593
# Time elapsed: 44.11 min
# Epoch: 064/150 | Batch 0000/0514 | Cost: 7.5474
# Epoch: 064/150 | Batch 0150/0514 | Cost: 7.5971
# Epoch: 064/150 | Batch 0300/0514 | Cost: 7.7640
# Epoch: 064/150 | Batch 0450/0514 | Cost: 7.3524
# Time elapsed: 44.87 min
# Epoch: 065/150 | Batch 0000/0514 | Cost: 7.4304
# Epoch: 065/150 | Batch 0150/0514 | Cost: 7.3685
# Epoch: 065/150 | Batch 0300/0514 | Cost: 7.2516
# Epoch: 065/150 | Batch 0450/0514 | Cost: 7.3711
# Time elapsed: 45.64 min
# Epoch: 066/150 | Batch 0000/0514 | Cost: 7.5385
# Epoch: 066/150 | Batch 0150/0514 | Cost: 7.4030
# Epoch: 066/150 | Batch 0300/0514 | Cost: 7.3331
# Epoch: 066/150 | Batch 0450/0514 | Cost: 7.6370
# Time elapsed: 46.40 min
# Epoch: 067/150 | Batch 0000/0514 | Cost: 7.1137
# Epoch: 067/150 | Batch 0150/0514 | Cost: 7.4180
# Epoch: 067/150 | Batch 0300/0514 | Cost: 7.1989
# Epoch: 067/150 | Batch 0450/0514 | Cost: 7.1889
# Time elapsed: 47.17 min
# Epoch: 068/150 | Batch 0000/0514 | Cost: 7.2209
# Epoch: 068/150 | Batch 0150/0514 | Cost: 7.4048
# Epoch: 068/150 | Batch 0300/0514 | Cost: 7.0798
# Epoch: 068/150 | Batch 0450/0514 | Cost: 7.3963
# Time elapsed: 47.94 min
# Epoch: 069/150 | Batch 0000/0514 | Cost: 7.2761
# Epoch: 069/150 | Batch 0150/0514 | Cost: 7.3383
# Epoch: 069/150 | Batch 0300/0514 | Cost: 7.2400
# Epoch: 069/150 | Batch 0450/0514 | Cost: 7.0873
# Time elapsed: 48.72 min
# Epoch: 070/150 | Batch 0000/0514 | Cost: 7.1075
# Epoch: 070/150 | Batch 0150/0514 | Cost: 7.2188
# Epoch: 070/150 | Batch 0300/0514 | Cost: 7.3112
# Epoch: 070/150 | Batch 0450/0514 | Cost: 7.0254
# Time elapsed: 49.49 min
# Epoch: 071/150 | Batch 0000/0514 | Cost: 7.1008
# Epoch: 071/150 | Batch 0150/0514 | Cost: 7.2036
# Epoch: 071/150 | Batch 0300/0514 | Cost: 7.0447
# Epoch: 071/150 | Batch 0450/0514 | Cost: 7.0773
# Time elapsed: 50.27 min
# Epoch: 072/150 | Batch 0000/0514 | Cost: 6.9951
# Epoch: 072/150 | Batch 0150/0514 | Cost: 7.0564
# Epoch: 072/150 | Batch 0300/0514 | Cost: 6.9431
# Epoch: 072/150 | Batch 0450/0514 | Cost: 6.8970
# Time elapsed: 51.04 min
# Epoch: 073/150 | Batch 0000/0514 | Cost: 6.9738
# Epoch: 073/150 | Batch 0150/0514 | Cost: 6.7895
# Epoch: 073/150 | Batch 0300/0514 | Cost: 7.0949
# Epoch: 073/150 | Batch 0450/0514 | Cost: 6.9147
# Time elapsed: 51.83 min
# Epoch: 074/150 | Batch 0000/0514 | Cost: 6.7700
# Epoch: 074/150 | Batch 0150/0514 | Cost: 6.9749
# Epoch: 074/150 | Batch 0300/0514 | Cost: 6.8681
# Epoch: 074/150 | Batch 0450/0514 | Cost: 6.9999
# Time elapsed: 52.61 min
# Epoch: 075/150 | Batch 0000/0514 | Cost: 6.6524
# Epoch: 075/150 | Batch 0150/0514 | Cost: 6.6734
# Epoch: 075/150 | Batch 0300/0514 | Cost: 6.9444
# Epoch: 075/150 | Batch 0450/0514 | Cost: 6.7931
# Time elapsed: 53.40 min
# Epoch: 076/150 | Batch 0000/0514 | Cost: 6.8584
# Epoch: 076/150 | Batch 0150/0514 | Cost: 6.6764
# Epoch: 076/150 | Batch 0300/0514 | Cost: 6.5774
# Epoch: 076/150 | Batch 0450/0514 | Cost: 6.7900
# Time elapsed: 54.19 min
# Epoch: 077/150 | Batch 0000/0514 | Cost: 6.8307
# Epoch: 077/150 | Batch 0150/0514 | Cost: 6.6436
# Epoch: 077/150 | Batch 0300/0514 | Cost: 6.7982
# Epoch: 077/150 | Batch 0450/0514 | Cost: 6.7264
# Time elapsed: 54.98 min
# Epoch: 078/150 | Batch 0000/0514 | Cost: 6.4560
# Epoch: 078/150 | Batch 0150/0514 | Cost: 6.7820
# Epoch: 078/150 | Batch 0300/0514 | Cost: 6.7053
# Epoch: 078/150 | Batch 0450/0514 | Cost: 6.6711
# Time elapsed: 55.76 min
# Epoch: 079/150 | Batch 0000/0514 | Cost: 6.6403
# Epoch: 079/150 | Batch 0150/0514 | Cost: 6.6845
# Epoch: 079/150 | Batch 0300/0514 | Cost: 6.6473
# Epoch: 079/150 | Batch 0450/0514 | Cost: 6.3889
# Time elapsed: 56.54 min
# Epoch: 080/150 | Batch 0000/0514 | Cost: 6.4673
# Epoch: 080/150 | Batch 0150/0514 | Cost: 6.4994
# Epoch: 080/150 | Batch 0300/0514 | Cost: 6.5805
# Epoch: 080/150 | Batch 0450/0514 | Cost: 6.6706
# Time elapsed: 57.33 min
# Epoch: 081/150 | Batch 0000/0514 | Cost: 6.4404
# Epoch: 081/150 | Batch 0150/0514 | Cost: 6.5357
# Epoch: 081/150 | Batch 0300/0514 | Cost: 6.2171
# Epoch: 081/150 | Batch 0450/0514 | Cost: 6.4990
# Time elapsed: 58.12 min
# Epoch: 082/150 | Batch 0000/0514 | Cost: 6.4322
# Epoch: 082/150 | Batch 0150/0514 | Cost: 6.3187
# Epoch: 082/150 | Batch 0300/0514 | Cost: 6.5639
# Epoch: 082/150 | Batch 0450/0514 | Cost: 6.5257
# Time elapsed: 58.89 min
# Epoch: 083/150 | Batch 0000/0514 | Cost: 6.3733
# Epoch: 083/150 | Batch 0150/0514 | Cost: 6.3751
# Epoch: 083/150 | Batch 0300/0514 | Cost: 6.2857
# Epoch: 083/150 | Batch 0450/0514 | Cost: 6.4726
# Time elapsed: 59.65 min
# Epoch: 084/150 | Batch 0000/0514 | Cost: 6.3850
# Epoch: 084/150 | Batch 0150/0514 | Cost: 6.3209
# Epoch: 084/150 | Batch 0300/0514 | Cost: 6.4002
# Epoch: 084/150 | Batch 0450/0514 | Cost: 6.3308
# Time elapsed: 60.44 min
# Epoch: 085/150 | Batch 0000/0514 | Cost: 6.4098
# Epoch: 085/150 | Batch 0150/0514 | Cost: 6.0459
# Epoch: 085/150 | Batch 0300/0514 | Cost: 6.1655
# Epoch: 085/150 | Batch 0450/0514 | Cost: 6.4399
# Time elapsed: 61.21 min
# Epoch: 086/150 | Batch 0000/0514 | Cost: 6.3586
# Epoch: 086/150 | Batch 0150/0514 | Cost: 6.3637
# Epoch: 086/150 | Batch 0300/0514 | Cost: 6.1989
# Epoch: 086/150 | Batch 0450/0514 | Cost: 6.2747
# Time elapsed: 62.00 min
# Epoch: 087/150 | Batch 0000/0514 | Cost: 6.1528
# Epoch: 087/150 | Batch 0150/0514 | Cost: 6.3247
# Epoch: 087/150 | Batch 0300/0514 | Cost: 6.3096
# Epoch: 087/150 | Batch 0450/0514 | Cost: 6.1344
# Time elapsed: 62.78 min
# Epoch: 088/150 | Batch 0000/0514 | Cost: 5.9539
# Epoch: 088/150 | Batch 0150/0514 | Cost: 6.2283
# Epoch: 088/150 | Batch 0300/0514 | Cost: 6.1846
# Epoch: 088/150 | Batch 0450/0514 | Cost: 6.0707
# Time elapsed: 63.55 min
# Epoch: 089/150 | Batch 0000/0514 | Cost: 6.1453
# Epoch: 089/150 | Batch 0150/0514 | Cost: 6.0650
# Epoch: 089/150 | Batch 0300/0514 | Cost: 6.0444
# Epoch: 089/150 | Batch 0450/0514 | Cost: 6.3047
# Time elapsed: 64.33 min
# Epoch: 090/150 | Batch 0000/0514 | Cost: 6.2708
# Epoch: 090/150 | Batch 0150/0514 | Cost: 5.9740
# Epoch: 090/150 | Batch 0300/0514 | Cost: 6.0108
# Epoch: 090/150 | Batch 0450/0514 | Cost: 6.3144
# Time elapsed: 65.09 min
# Epoch: 091/150 | Batch 0000/0514 | Cost: 5.9728
# Epoch: 091/150 | Batch 0150/0514 | Cost: 5.9366
# Epoch: 091/150 | Batch 0300/0514 | Cost: 5.8523
# Epoch: 091/150 | Batch 0450/0514 | Cost: 6.0699
# Time elapsed: 65.88 min
# Epoch: 092/150 | Batch 0000/0514 | Cost: 5.9333
# Epoch: 092/150 | Batch 0150/0514 | Cost: 5.9628
# Epoch: 092/150 | Batch 0300/0514 | Cost: 5.9939
# Epoch: 092/150 | Batch 0450/0514 | Cost: 5.8899
# Time elapsed: 66.65 min
# Epoch: 093/150 | Batch 0000/0514 | Cost: 5.7671
# Epoch: 093/150 | Batch 0150/0514 | Cost: 5.9780
# Epoch: 093/150 | Batch 0300/0514 | Cost: 6.1139
# Epoch: 093/150 | Batch 0450/0514 | Cost: 5.9771
# Time elapsed: 67.43 min
# Epoch: 094/150 | Batch 0000/0514 | Cost: 5.8104
# Epoch: 094/150 | Batch 0150/0514 | Cost: 5.9176
# Epoch: 094/150 | Batch 0300/0514 | Cost: 5.7630
# Epoch: 094/150 | Batch 0450/0514 | Cost: 5.6246
# Time elapsed: 68.21 min
# Epoch: 095/150 | Batch 0000/0514 | Cost: 5.9229
# Epoch: 095/150 | Batch 0150/0514 | Cost: 6.0474
# Epoch: 095/150 | Batch 0300/0514 | Cost: 5.8047
# Epoch: 095/150 | Batch 0450/0514 | Cost: 5.8098
# Time elapsed: 68.98 min
# Epoch: 096/150 | Batch 0000/0514 | Cost: 5.7826
# Epoch: 096/150 | Batch 0150/0514 | Cost: 5.9622
# Epoch: 096/150 | Batch 0300/0514 | Cost: 5.7704
# Epoch: 096/150 | Batch 0450/0514 | Cost: 5.9028
# Time elapsed: 69.75 min
# Epoch: 097/150 | Batch 0000/0514 | Cost: 5.8011
# Epoch: 097/150 | Batch 0150/0514 | Cost: 5.6642
# Epoch: 097/150 | Batch 0300/0514 | Cost: 5.6756
# Epoch: 097/150 | Batch 0450/0514 | Cost: 5.8870
# Time elapsed: 70.53 min
# Epoch: 098/150 | Batch 0000/0514 | Cost: 5.7508
# Epoch: 098/150 | Batch 0150/0514 | Cost: 5.8374
# Epoch: 098/150 | Batch 0300/0514 | Cost: 5.8317
# Epoch: 098/150 | Batch 0450/0514 | Cost: 5.7567
# Time elapsed: 71.31 min
# Epoch: 099/150 | Batch 0000/0514 | Cost: 5.6441
# Epoch: 099/150 | Batch 0150/0514 | Cost: 5.4338
# Epoch: 099/150 | Batch 0300/0514 | Cost: 5.6338
# Epoch: 099/150 | Batch 0450/0514 | Cost: 5.5249
# Time elapsed: 72.09 min
# Epoch: 100/150 | Batch 0000/0514 | Cost: 5.5255
# Epoch: 100/150 | Batch 0150/0514 | Cost: 5.6232
# Epoch: 100/150 | Batch 0300/0514 | Cost: 5.4772
# Epoch: 100/150 | Batch 0450/0514 | Cost: 5.6324
# Time elapsed: 72.86 min
# Epoch: 101/150 | Batch 0000/0514 | Cost: 5.3753
# Epoch: 101/150 | Batch 0150/0514 | Cost: 5.6045
# Epoch: 101/150 | Batch 0300/0514 | Cost: 5.6958
# Epoch: 101/150 | Batch 0450/0514 | Cost: 5.8287
# Time elapsed: 73.64 min
# Epoch: 102/150 | Batch 0000/0514 | Cost: 5.3470
# Epoch: 102/150 | Batch 0150/0514 | Cost: 5.5973
# Epoch: 102/150 | Batch 0300/0514 | Cost: 5.5314
# Epoch: 102/150 | Batch 0450/0514 | Cost: 5.4421
# Time elapsed: 74.42 min
# Epoch: 103/150 | Batch 0000/0514 | Cost: 5.4303
# Epoch: 103/150 | Batch 0150/0514 | Cost: 5.6858
# Epoch: 103/150 | Batch 0300/0514 | Cost: 5.5884
# Epoch: 103/150 | Batch 0450/0514 | Cost: 5.4960
# Time elapsed: 75.19 min
# Epoch: 104/150 | Batch 0000/0514 | Cost: 5.5690
# Epoch: 104/150 | Batch 0150/0514 | Cost: 5.6294
# Epoch: 104/150 | Batch 0300/0514 | Cost: 5.5028
# Epoch: 104/150 | Batch 0450/0514 | Cost: 5.4706
# Time elapsed: 75.98 min
# Epoch: 105/150 | Batch 0000/0514 | Cost: 5.3198
# Epoch: 105/150 | Batch 0150/0514 | Cost: 5.4230
# Epoch: 105/150 | Batch 0300/0514 | Cost: 5.3051
# Epoch: 105/150 | Batch 0450/0514 | Cost: 5.5209
# Time elapsed: 76.76 min
# Epoch: 106/150 | Batch 0000/0514 | Cost: 5.5428
# Epoch: 106/150 | Batch 0150/0514 | Cost: 5.3923
# Epoch: 106/150 | Batch 0300/0514 | Cost: 5.3473
# Epoch: 106/150 | Batch 0450/0514 | Cost: 5.3489
# Time elapsed: 77.53 min
# Epoch: 107/150 | Batch 0000/0514 | Cost: 5.3284
# Epoch: 107/150 | Batch 0150/0514 | Cost: 5.2702
# Epoch: 107/150 | Batch 0300/0514 | Cost: 5.4636
# Epoch: 107/150 | Batch 0450/0514 | Cost: 5.2698
# Time elapsed: 78.31 min
# Epoch: 108/150 | Batch 0000/0514 | Cost: 5.3362
# Epoch: 108/150 | Batch 0150/0514 | Cost: 5.2593
# Epoch: 108/150 | Batch 0300/0514 | Cost: 5.3391
# Epoch: 108/150 | Batch 0450/0514 | Cost: 5.5070
# Time elapsed: 79.09 min
# Epoch: 109/150 | Batch 0000/0514 | Cost: 5.3897
# Epoch: 109/150 | Batch 0150/0514 | Cost: 5.2680
# Epoch: 109/150 | Batch 0300/0514 | Cost: 5.1659
# Epoch: 109/150 | Batch 0450/0514 | Cost: 5.4636
# Time elapsed: 79.86 min
# Epoch: 110/150 | Batch 0000/0514 | Cost: 5.2862
# Epoch: 110/150 | Batch 0150/0514 | Cost: 5.2302
# Epoch: 110/150 | Batch 0300/0514 | Cost: 5.3187
# Epoch: 110/150 | Batch 0450/0514 | Cost: 5.3557
# Time elapsed: 80.64 min
# Epoch: 111/150 | Batch 0000/0514 | Cost: 5.1602
# Epoch: 111/150 | Batch 0150/0514 | Cost: 5.0355
# Epoch: 111/150 | Batch 0300/0514 | Cost: 5.2647
# Epoch: 111/150 | Batch 0450/0514 | Cost: 5.1989
# Time elapsed: 81.42 min
# Epoch: 112/150 | Batch 0000/0514 | Cost: 5.1090
# Epoch: 112/150 | Batch 0150/0514 | Cost: 5.1730
# Epoch: 112/150 | Batch 0300/0514 | Cost: 5.2870
# Epoch: 112/150 | Batch 0450/0514 | Cost: 5.2381
# Time elapsed: 82.21 min
# Epoch: 113/150 | Batch 0000/0514 | Cost: 5.0724
# Epoch: 113/150 | Batch 0150/0514 | Cost: 5.0151
# Epoch: 113/150 | Batch 0300/0514 | Cost: 5.3452
# Epoch: 113/150 | Batch 0450/0514 | Cost: 5.3667
# Time elapsed: 82.99 min
# Epoch: 114/150 | Batch 0000/0514 | Cost: 5.3323
# Epoch: 114/150 | Batch 0150/0514 | Cost: 5.1088
# Epoch: 114/150 | Batch 0300/0514 | Cost: 5.1146
# Epoch: 114/150 | Batch 0450/0514 | Cost: 5.0487
# Time elapsed: 83.77 min
# Epoch: 115/150 | Batch 0000/0514 | Cost: 5.0847
# Epoch: 115/150 | Batch 0150/0514 | Cost: 5.2190
# Epoch: 115/150 | Batch 0300/0514 | Cost: 4.9494
# Epoch: 115/150 | Batch 0450/0514 | Cost: 5.1312
# Time elapsed: 84.55 min
# Epoch: 116/150 | Batch 0000/0514 | Cost: 5.0108
# Epoch: 116/150 | Batch 0150/0514 | Cost: 5.1513
# Epoch: 116/150 | Batch 0300/0514 | Cost: 4.9192
# Epoch: 116/150 | Batch 0450/0514 | Cost: 5.0243
# Time elapsed: 85.32 min
# Epoch: 117/150 | Batch 0000/0514 | Cost: 4.9644
# Epoch: 117/150 | Batch 0150/0514 | Cost: 4.9044
# Epoch: 117/150 | Batch 0300/0514 | Cost: 5.1677
# Epoch: 117/150 | Batch 0450/0514 | Cost: 5.0949
# Time elapsed: 86.10 min
# Epoch: 118/150 | Batch 0000/0514 | Cost: 5.0092
# Epoch: 118/150 | Batch 0150/0514 | Cost: 5.1942
# Epoch: 118/150 | Batch 0300/0514 | Cost: 4.8766
# Epoch: 118/150 | Batch 0450/0514 | Cost: 4.8894
# Time elapsed: 86.86 min
# Epoch: 119/150 | Batch 0000/0514 | Cost: 4.8320
# Epoch: 119/150 | Batch 0150/0514 | Cost: 4.9640
# Epoch: 119/150 | Batch 0300/0514 | Cost: 4.9843
# Epoch: 119/150 | Batch 0450/0514 | Cost: 4.9165
# Time elapsed: 87.64 min
# Epoch: 120/150 | Batch 0000/0514 | Cost: 4.9706
# Epoch: 120/150 | Batch 0150/0514 | Cost: 4.9305
# Epoch: 120/150 | Batch 0300/0514 | Cost: 5.0859
# Epoch: 120/150 | Batch 0450/0514 | Cost: 4.9544
# Time elapsed: 88.43 min
# Epoch: 121/150 | Batch 0000/0514 | Cost: 4.8325
# Epoch: 121/150 | Batch 0150/0514 | Cost: 4.8016
# Epoch: 121/150 | Batch 0300/0514 | Cost: 4.9929
# Epoch: 121/150 | Batch 0450/0514 | Cost: 4.9303
# Time elapsed: 89.21 min
# Epoch: 122/150 | Batch 0000/0514 | Cost: 4.8489
# Epoch: 122/150 | Batch 0150/0514 | Cost: 4.8509
# Epoch: 122/150 | Batch 0300/0514 | Cost: 4.6510
# Epoch: 122/150 | Batch 0450/0514 | Cost: 4.7916
# Time elapsed: 89.99 min
# Epoch: 123/150 | Batch 0000/0514 | Cost: 4.7846
# Epoch: 123/150 | Batch 0150/0514 | Cost: 4.8874
# Epoch: 123/150 | Batch 0300/0514 | Cost: 4.8363
# Epoch: 123/150 | Batch 0450/0514 | Cost: 4.8457
# Time elapsed: 90.77 min
# Epoch: 124/150 | Batch 0000/0514 | Cost: 4.7403
# Epoch: 124/150 | Batch 0150/0514 | Cost: 4.7603
# Epoch: 124/150 | Batch 0300/0514 | Cost: 4.9158
# Epoch: 124/150 | Batch 0450/0514 | Cost: 4.8251
# Time elapsed: 91.55 min
# Epoch: 125/150 | Batch 0000/0514 | Cost: 4.8213
# Epoch: 125/150 | Batch 0150/0514 | Cost: 4.9703
# Epoch: 125/150 | Batch 0300/0514 | Cost: 4.8026
# Epoch: 125/150 | Batch 0450/0514 | Cost: 4.8964
# Time elapsed: 92.33 min
# Epoch: 126/150 | Batch 0000/0514 | Cost: 4.8183
# Epoch: 126/150 | Batch 0150/0514 | Cost: 4.7550
# Epoch: 126/150 | Batch 0300/0514 | Cost: 4.6373
# Epoch: 126/150 | Batch 0450/0514 | Cost: 4.9195
# Time elapsed: 93.11 min
# Epoch: 127/150 | Batch 0000/0514 | Cost: 4.7866
# Epoch: 127/150 | Batch 0150/0514 | Cost: 4.7312
# Epoch: 127/150 | Batch 0300/0514 | Cost: 4.6813
# Epoch: 127/150 | Batch 0450/0514 | Cost: 4.8444
# Time elapsed: 93.89 min
# Epoch: 128/150 | Batch 0000/0514 | Cost: 4.7906
# Epoch: 128/150 | Batch 0150/0514 | Cost: 4.6574
# Epoch: 128/150 | Batch 0300/0514 | Cost: 4.7626
# Epoch: 128/150 | Batch 0450/0514 | Cost: 4.6578
# Time elapsed: 94.65 min
# Epoch: 129/150 | Batch 0000/0514 | Cost: 4.6934
# Epoch: 129/150 | Batch 0150/0514 | Cost: 4.6159
# Epoch: 129/150 | Batch 0300/0514 | Cost: 4.6196
# Epoch: 129/150 | Batch 0450/0514 | Cost: 4.7298
# Time elapsed: 95.44 min
# Epoch: 130/150 | Batch 0000/0514 | Cost: 4.6744
# Epoch: 130/150 | Batch 0150/0514 | Cost: 4.8783
# Epoch: 130/150 | Batch 0300/0514 | Cost: 4.7351
# Epoch: 130/150 | Batch 0450/0514 | Cost: 4.6222
# Time elapsed: 96.23 min
# Epoch: 131/150 | Batch 0000/0514 | Cost: 4.6389
# Epoch: 131/150 | Batch 0150/0514 | Cost: 4.8389
# Epoch: 131/150 | Batch 0300/0514 | Cost: 4.8584
# Epoch: 131/150 | Batch 0450/0514 | Cost: 4.6619
# Time elapsed: 96.99 min
# Epoch: 132/150 | Batch 0000/0514 | Cost: 4.8030
# Epoch: 132/150 | Batch 0150/0514 | Cost: 4.6689
# Epoch: 132/150 | Batch 0300/0514 | Cost: 4.6524
# Epoch: 132/150 | Batch 0450/0514 | Cost: 4.6141
# Time elapsed: 97.76 min
# Epoch: 133/150 | Batch 0000/0514 | Cost: 4.5489
# Epoch: 133/150 | Batch 0150/0514 | Cost: 4.6171
# Epoch: 133/150 | Batch 0300/0514 | Cost: 4.6758
# Epoch: 133/150 | Batch 0450/0514 | Cost: 4.6891
# Time elapsed: 98.54 min
# Epoch: 134/150 | Batch 0000/0514 | Cost: 4.4744
# Epoch: 134/150 | Batch 0150/0514 | Cost: 4.5310
# Epoch: 134/150 | Batch 0300/0514 | Cost: 4.6393
# Epoch: 134/150 | Batch 0450/0514 | Cost: 4.5449
# Time elapsed: 99.31 min
# Epoch: 135/150 | Batch 0000/0514 | Cost: 4.4347
# Epoch: 135/150 | Batch 0150/0514 | Cost: 4.5465
# Epoch: 135/150 | Batch 0300/0514 | Cost: 4.4673
# Epoch: 135/150 | Batch 0450/0514 | Cost: 4.5124
# Time elapsed: 100.08 min
# Epoch: 136/150 | Batch 0000/0514 | Cost: 4.6078
# Epoch: 136/150 | Batch 0150/0514 | Cost: 4.5858
# Epoch: 136/150 | Batch 0300/0514 | Cost: 4.5957
# Epoch: 136/150 | Batch 0450/0514 | Cost: 4.6318
# Time elapsed: 100.86 min
# Epoch: 137/150 | Batch 0000/0514 | Cost: 4.5069
# Epoch: 137/150 | Batch 0150/0514 | Cost: 4.5587
# Epoch: 137/150 | Batch 0300/0514 | Cost: 4.6860
# Epoch: 137/150 | Batch 0450/0514 | Cost: 4.5521
# Time elapsed: 101.64 min
# Epoch: 138/150 | Batch 0000/0514 | Cost: 4.5441
# Epoch: 138/150 | Batch 0150/0514 | Cost: 4.4487
# Epoch: 138/150 | Batch 0300/0514 | Cost: 4.5158
# Epoch: 138/150 | Batch 0450/0514 | Cost: 4.4299
# Time elapsed: 102.43 min
# Epoch: 139/150 | Batch 0000/0514 | Cost: 4.3427
# Epoch: 139/150 | Batch 0150/0514 | Cost: 4.4906
# Epoch: 139/150 | Batch 0300/0514 | Cost: 4.4251
# Epoch: 139/150 | Batch 0450/0514 | Cost: 4.3842
# Time elapsed: 103.20 min
# Epoch: 140/150 | Batch 0000/0514 | Cost: 4.3576
# Epoch: 140/150 | Batch 0150/0514 | Cost: 4.4947
# Epoch: 140/150 | Batch 0300/0514 | Cost: 4.5034
# Epoch: 140/150 | Batch 0450/0514 | Cost: 4.4965
# Time elapsed: 103.99 min
# Epoch: 141/150 | Batch 0000/0514 | Cost: 4.5300
# Epoch: 141/150 | Batch 0150/0514 | Cost: 4.4212
# Epoch: 141/150 | Batch 0300/0514 | Cost: 4.4612
# Epoch: 141/150 | Batch 0450/0514 | Cost: 4.5316
# Time elapsed: 104.76 min
# Epoch: 142/150 | Batch 0000/0514 | Cost: 4.3705
# Epoch: 142/150 | Batch 0150/0514 | Cost: 4.5454
# Epoch: 142/150 | Batch 0300/0514 | Cost: 4.4046
# Epoch: 142/150 | Batch 0450/0514 | Cost: 4.3169
# Time elapsed: 105.54 min
# Epoch: 143/150 | Batch 0000/0514 | Cost: 4.3973
# Epoch: 143/150 | Batch 0150/0514 | Cost: 4.4054
# Epoch: 143/150 | Batch 0300/0514 | Cost: 4.2793
# Epoch: 143/150 | Batch 0450/0514 | Cost: 4.3064
# Time elapsed: 106.32 min
# Epoch: 144/150 | Batch 0000/0514 | Cost: 4.3659
# Epoch: 144/150 | Batch 0150/0514 | Cost: 4.1300
# Epoch: 144/150 | Batch 0300/0514 | Cost: 4.3086
# Epoch: 144/150 | Batch 0450/0514 | Cost: 4.3859
# Time elapsed: 107.10 min
# Epoch: 145/150 | Batch 0000/0514 | Cost: 4.3345
# Epoch: 145/150 | Batch 0150/0514 | Cost: 4.3569
# Epoch: 145/150 | Batch 0300/0514 | Cost: 4.3164
# Epoch: 145/150 | Batch 0450/0514 | Cost: 4.1909
# Time elapsed: 107.89 min
# Epoch: 146/150 | Batch 0000/0514 | Cost: 4.5213
# Epoch: 146/150 | Batch 0150/0514 | Cost: 4.3658
# Epoch: 146/150 | Batch 0300/0514 | Cost: 4.1937
# Epoch: 146/150 | Batch 0450/0514 | Cost: 4.2117
# Time elapsed: 108.66 min
# Epoch: 147/150 | Batch 0000/0514 | Cost: 4.3113
# Epoch: 147/150 | Batch 0150/0514 | Cost: 4.3375
# Epoch: 147/150 | Batch 0300/0514 | Cost: 4.3998
# Epoch: 147/150 | Batch 0450/0514 | Cost: 4.3652
# Time elapsed: 109.44 min
# Epoch: 148/150 | Batch 0000/0514 | Cost: 4.0811
# Epoch: 148/150 | Batch 0150/0514 | Cost: 4.3050
# Epoch: 148/150 | Batch 0300/0514 | Cost: 4.2519
# Epoch: 148/150 | Batch 0450/0514 | Cost: 4.3828
# Time elapsed: 110.22 min
# Epoch: 149/150 | Batch 0000/0514 | Cost: 4.2677
# Epoch: 149/150 | Batch 0150/0514 | Cost: 4.2427
# Epoch: 149/150 | Batch 0300/0514 | Cost: 4.2232
# Epoch: 149/150 | Batch 0450/0514 | Cost: 4.3284
# Time elapsed: 111.01 min
# Epoch: 150/150 | Batch 0000/0514 | Cost: 4.1556
# Epoch: 150/150 | Batch 0150/0514 | Cost: 4.1423
# Epoch: 150/150 | Batch 0300/0514 | Cost: 4.2055
# Epoch: 150/150 | Batch 0450/0514 | Cost: 4.3414
# Time elapsed: 111.79 min

# %% [markdown]
# ## Evaluation

# %%
model.eval()
with torch.set_grad_enabled(False):  # save memory during inference

    train_mae, train_mse = compute_mae_and_mse(model, train_loader,
                                               device=DEVICE)
    test_mae, test_mse = compute_mae_and_mse(model, test_loader,
                                             device=DEVICE)

    s = 'MAE/RMSE: | Train: %.2f/%.2f | Test: %.2f/%.2f' % (
        train_mae, torch.sqrt(train_mse), test_mae, torch.sqrt(test_mse))
    print(s)

s = 'Total Training Time: %.2f min' % ((time.time() - start_time)/60)
print(s)
# Out:
# MAE/RMSE: | Train: 1.19/1.64 | Test: 3.78/5.14
# Total Training Time: 112.72 min

# %%
# %watermark -iv
# Out:
# numpy       1.15.4
# pandas      0.23.4
# torch       1.1.0
# PIL.Image   5.3.0
